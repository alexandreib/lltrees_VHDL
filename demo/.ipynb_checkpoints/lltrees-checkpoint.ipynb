# %%
import time

import numpy as np
import pandas as pd
import sklearn.datasets, sklearn.metrics, sklearn.model_selection, sklearn.tree

import subprocess, sys

# %%
# !cd ../ && make print-SOURCES
# Out:
# SOURCES = cpp/conf.cpp cpp/criterion.cpp cpp/factories.cpp cpp/gbt.cpp cpp/lltrees.cpp cpp/metrics.cpp cpp/node.cpp cpp/threadpool.cpp cpp/tree.cpp cpp/wrapper.cpp

# %%
X, Y = sklearn.datasets.make_classification(n_samples=1000, n_features=8, n_informative=5, n_classes=2, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# !cd ../ && make clean
# !cd ../ && make
subprocess.call([sys.executable, "lltrees_python_import_for_debug.py"])
# Out:
# g++ -g -o build/gbt.o cpp/gbt.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/lltrees.so build/conf.o build/criterion.o build/factories.o build/gbt.o build/lltrees.o build/metrics.o build/node.o build/threadpool.o build/tree.o build/wrapper.o -L/usr/lib/python3.10/config-3.10-x86_64-linux-gnu -L/usr/lib/x86_64-linux-gnu  -lcrypt -ldl  -lm -lm  -shared -Wl,-rpath,/usr/lib  -lpython3.10 -lboost_python310 -lboost_numpy310
# -----------------------------------------
# mode :              classification
# epochs :            50
# learning_rate :     0.1
# metric :            accuracy
# criterion :         gini
# max_depth :         1
# min_leaf_size :     1
# verbose :           1
# -----------------------------------------
# Type of Training Data : int32
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0 1
# Epoch : 1     Metric Train : 0.724286 Metric va : 0.723333 Residuals (mean) : 0.724286
# Epoch : 2     Metric Train : 0.724286 Metric va : 0.723333 Residuals (mean) : 0.724286
# Epoch : 3     Metric Train : 0.724286 Metric va : 0.723333 Residuals (mean) : 0.724286
# Epoch : 4     Metric Train : 0.72    Metric va : 0.71    Residuals (mean) : 0.72
# Epoch : 5     Metric Train : 0.72    Metric va : 0.71    Residuals (mean) : 0.72
# Epoch : 6     Metric Train : 0.725714 Metric va : 0.71    Residuals (mean) : 0.725714
# Epoch : 7     Metric Train : 0.731429 Metric va : 0.713333 Residuals (mean) : 0.731429
# Epoch : 8     Metric Train : 0.731429 Metric va : 0.716667 Residuals (mean) : 0.731429
# Epoch : 9     Metric Train : 0.724286 Metric va : 0.713333 Residuals (mean) : 0.724286
# Epoch : 10    Metric Train : 0.725714 Metric va : 0.713333 Residuals (mean) : 0.725714
# Epoch : 11    Metric Train : 0.73    Metric va : 0.716667 Residuals (mean) : 0.73
# Epoch : 12    Metric Train : 0.73    Metric va : 0.716667 Residuals (mean) : 0.73
# Epoch : 13    Metric Train : 0.731429 Metric va : 0.716667 Residuals (mean) : 0.731429
# Epoch : 14    Metric Train : 0.734286 Metric va : 0.703333 Residuals (mean) : 0.734286
# Epoch : 15    Metric Train : 0.734286 Metric va : 0.703333 Residuals (mean) : 0.734286
# Epoch : 16    Metric Train : 0.737143 Metric va : 0.7     Residuals (mean) : 0.737143
# Epoch : 17    Metric Train : 0.74    Metric va : 0.71    Residuals (mean) : 0.74
# Epoch : 18    Metric Train : 0.74    Metric va : 0.71    Residuals (mean) : 0.74
# Epoch : 19    Metric Train : 0.74    Metric va : 0.71    Residuals (mean) : 0.74
# Epoch : 20    Metric Train : 0.74    Metric va : 0.71    Residuals (mean) : 0.74
# Epoch : 21    Metric Train : 0.732857 Metric va : 0.696667 Residuals (mean) : 0.732857
# Epoch : 22    Metric Train : 0.73    Metric va : 0.686667 Residuals (mean) : 0.73
# Epoch : 23    Metric Train : 0.73    Metric va : 0.686667 Residuals (mean) : 0.73
# Epoch : 24    Metric Train : 0.737143 Metric va : 0.7     Residuals (mean) : 0.737143
# Epoch : 25    Metric Train : 0.74    Metric va : 0.706667 Residuals (mean) : 0.74
# Epoch : 26    Metric Train : 0.734286 Metric va : 0.693333 Residuals (mean) : 0.734286
# Epoch : 27    Metric Train : 0.732857 Metric va : 0.693333 Residuals (mean) : 0.732857
# Epoch : 28    Metric Train : 0.74    Metric va : 0.7     Residuals (mean) : 0.74
# Epoch : 29    Metric Train : 0.74    Metric va : 0.7     Residuals (mean) : 0.74
# Epoch : 30    Metric Train : 0.742857 Metric va : 0.706667 Residuals (mean) : 0.742857
# Epoch : 31    Metric Train : 0.727143 Metric va : 0.68    Residuals (mean) : 0.727143
# Epoch : 32    Metric Train : 0.727143 Metric va : 0.68    Residuals (mean) : 0.727143
# Epoch : 33    Metric Train : 0.727143 Metric va : 0.68    Residuals (mean) : 0.727143
# Epoch : 34    Metric Train : 0.727143 Metric va : 0.68    Residuals (mean) : 0.727143
# Epoch : 35    Metric Train : 0.725714 Metric va : 0.68    Residuals (mean) : 0.725714
# Epoch : 36    Metric Train : 0.744286 Metric va : 0.706667 Residuals (mean) : 0.744286
# Epoch : 37    Metric Train : 0.727143 Metric va : 0.683333 Residuals (mean) : 0.727143
# Epoch : 38    Metric Train : 0.727143 Metric va : 0.686667 Residuals (mean) : 0.727143
# Epoch : 39    Metric Train : 0.74    Metric va : 0.703333 Residuals (mean) : 0.74
# Epoch : 40    Metric Train : 0.732857 Metric va : 0.69    Residuals (mean) : 0.732857
# Epoch : 41    Metric Train : 0.732857 Metric va : 0.69    Residuals (mean) : 0.732857
# Epoch : 42    Metric Train : 0.731429 Metric va : 0.693333 Residuals (mean) : 0.731429
# Epoch : 43    Metric Train : 0.732857 Metric va : 0.693333 Residuals (mean) : 0.732857
# Epoch : 44    Metric Train : 0.732857 Metric va : 0.693333 Residuals (mean) : 0.732857
# Epoch : 45    Metric Train : 0.737143 Metric va : 0.696667 Residuals (mean) : 0.737143
# Epoch : 46    Metric Train : 0.732857 Metric va : 0.69    Residuals (mean) : 0.732857
# Epoch : 47    Metric Train : 0.732857 Metric va : 0.69    Residuals (mean) : 0.732857
# Epoch : 48    Metric Train : 0.727143 Metric va : 0.686667 Residuals (mean) : 0.727143
# Epoch : 49    Metric Train : 0.727143 Metric va : 0.686667 Residuals (mean) : 0.727143
# Epoch : 50    Metric Train : 0.728571 Metric va : 0.686667 Residuals (mean) : 0.728571
# FIT --- 3.8072903156280518 seconds ---
# Print.
# Tree : 0
# └──1, criterion: 0.499669, size: 700
#     ├──2, criterion: 0.281728, leaf_value: 1, size: 224
#     └──3, criterion: 0.43919, leaf_value: 0, size: 476
# Tree : 1
# └──1, criterion: 0.499969, size: 700
#     ├──2, criterion: 0.272784, leaf_value: 1, size: 207
#     └──3, criterion: 0.45822, leaf_value: 0, size: 493
# Tree : 2
# └──1, criterion: 0.499914, size: 700
#     ├──2, criterion: 0.190797, leaf_value: 1, size: 157
#     └──3, criterion: 0.480152, leaf_value: 0, size: 543
# Tree : 3
# └──1, criterion: 0.499107, size: 700
#     ├──2, criterion: 0.232931, leaf_value: 1, size: 170
#     └──3, criterion: 0.4867, leaf_value: 0, size: 530
# Tree : 4
# └──1, criterion: 0.497529, size: 700
#     ├──2, criterion: 0.222398, leaf_value: 1, size: 157
#     └──3, criterion: 0.494578, leaf_value: 0, size: 543
# Tree : 5
# └──1, criterion: 0.494907, size: 700
#     ├──2, criterion: 0.499288, leaf_value: 0, size: 574
#     └──3, criterion: 0.163047, leaf_value: 1, size: 126
# Tree : 6
# └──1, criterion: 0.49077, size: 700
#     ├──2, criterion: 0.346351, leaf_value: 0, size: 141
#     └──3, criterion: 0.458667, leaf_value: 1, size: 559
# Tree : 7
# └──1, criterion: 0.494416, size: 700
#     ├──2, criterion: 0.49386, leaf_value: 0, size: 561
#     └──3, criterion: 0.21657, leaf_value: 1, size: 139
# Tree : 8
# └──1, criterion: 0.491237, size: 700
#     ├──2, criterion: 0.306414, leaf_value: 1, size: 224
#     └──3, criterion: 0.496244, leaf_value: 0, size: 476
# Tree : 9
# └──1, criterion: 0.488234, size: 700
#     ├──2, criterion: 0.233116, leaf_value: 1, size: 157
#     └──3, criterion: 0.499932, leaf_value: 0, size: 543
# Tree : 10
# └──1, criterion: 0.482905, size: 700
#     ├──2, criterion: 0.356003, leaf_value: 0, size: 125
#     └──3, criterion: 0.451067, leaf_value: 1, size: 575
# Tree : 11
# └──1, criterion: 0.488351, size: 700
#     ├──2, criterion: 0.4288, leaf_value: 1, size: 425
#     └──3, criterion: 0.457312, leaf_value: 0, size: 275
# Tree : 12
# └──1, criterion: 0.490391, size: 700
#     ├──2, criterion: 0.499859, leaf_value: 0, size: 574
#     └──3, criterion: 0.177392, leaf_value: 1, size: 126
# Tree : 13
# └──1, criterion: 0.484851, size: 700
#     ├──2, criterion: 0.497777, leaf_value: 0, size: 574
#     └──3, criterion: 0.192054, leaf_value: 1, size: 126
# Tree : 14
# └──1, criterion: 0.478009, size: 700
#     ├──2, criterion: 0.339389, leaf_value: 0, size: 102
#     └──3, criterion: 0.451969, leaf_value: 1, size: 598
# Tree : 15
# └──1, criterion: 0.484839, size: 700
#     ├──2, criterion: 0.333041, leaf_value: 1, size: 230
#     └──3, criterion: 0.493464, leaf_value: 0, size: 470
# Tree : 16
# └──1, criterion: 0.482832, size: 700
#     ├──2, criterion: 0.237502, leaf_value: 1, size: 157
#     └──3, criterion: 0.498251, leaf_value: 0, size: 543
# Tree : 17
# └──1, criterion: 0.476394, size: 700
#     ├──2, criterion: 0.362219, leaf_value: 0, size: 102
#     └──3, criterion: 0.451855, leaf_value: 1, size: 598
# Tree : 18
# └──1, criterion: 0.483532, size: 700
#     ├──2, criterion: 0.238047, leaf_value: 1, size: 146
#     └──3, criterion: 0.497347, leaf_value: 0, size: 554
# Tree : 19
# └──1, criterion: 0.476799, size: 700
#     ├──2, criterion: 0.451783, leaf_value: 1, size: 594
#     └──3, criterion: 0.381672, leaf_value: 0, size: 106
# Tree : 20
# └──1, criterion: 0.483734, size: 700
#     ├──2, criterion: 0.499591, leaf_value: 0, size: 561
#     └──3, criterion: 0.226442, leaf_value: 1, size: 139
# Tree : 21
# └──1, criterion: 0.4789, size: 700
#     ├──2, criterion: 0.493875, leaf_value: 0, size: 574
#     └──3, criterion: 0.208461, leaf_value: 1, size: 126
# Tree : 22
# └──1, criterion: 0.47094, size: 700
#     ├──2, criterion: 0.264457, leaf_value: 0, size: 63
#     └──3, criterion: 0.453921, leaf_value: 1, size: 637
# Tree : 23
# └──1, criterion: 0.479856, size: 700
#     ├──2, criterion: 0.33452, leaf_value: 1, size: 236
#     └──3, criterion: 0.499518, leaf_value: 0, size: 464
# Tree : 24
# └──1, criterion: 0.475519, size: 700
#     ├──2, criterion: 0.417805, leaf_value: 1, size: 425
#     └──3, criterion: 0.482066, leaf_value: 0, size: 275
# Tree : 25
# └──1, criterion: 0.478837, size: 700
#     ├──2, criterion: 0.490658, leaf_value: 0, size: 597
#     └──3, criterion: 0.185765, leaf_value: 1, size: 103
# Tree : 26
# └──1, criterion: 0.470061, size: 700
#     ├──2, criterion: 0.423828, leaf_value: 0, size: 125
#     └──3, criterion: 0.441084, leaf_value: 1, size: 575
# Tree : 27
# └──1, criterion: 0.477556, size: 700
#     ├──2, criterion: 0.265854, leaf_value: 1, size: 146
#     └──3, criterion: 0.492092, leaf_value: 0, size: 554
# Tree : 28
# └──1, criterion: 0.469641, size: 700
#     ├──2, criterion: 0.293522, leaf_value: 0, size: 63
#     └──3, criterion: 0.454307, leaf_value: 1, size: 637
# Tree : 29
# └──1, criterion: 0.478849, size: 700
#     ├──2, criterion: 0.343103, leaf_value: 1, size: 230
#     └──3, criterion: 0.497636, leaf_value: 0, size: 470
# Tree : 30
# └──1, criterion: 0.476871, size: 700
#     ├──2, criterion: 0.490092, leaf_value: 0, size: 574
#     └──3, criterion: 0.252133, leaf_value: 1, size: 126
# Tree : 31
# └──1, criterion: 0.468377, size: 700
#     ├──2, criterion: 0.275537, leaf_value: 1, size: 146
#     └──3, criterion: 0.484149, leaf_value: 0, size: 554
# Tree : 32
# └──1, criterion: 0.45916, size: 700
#     ├──2, criterion: 0.0946613, leaf_value: 0, size: 34
#     └──3, criterion: 0.448339, leaf_value: 1, size: 666
# Tree : 33
# └──1, criterion: 0.47051, size: 700
#     ├──2, criterion: 0.334655, leaf_value: 0, size: 70
#     └──3, criterion: 0.455809, leaf_value: 1, size: 630
# Tree : 34
# └──1, criterion: 0.479535, size: 700
#     ├──2, criterion: 0.499854, leaf_value: 0, size: 528
#     └──3, criterion: 0.29522, leaf_value: 1, size: 172
# Tree : 35
# └──1, criterion: 0.475491, size: 700
#     ├──2, criterion: 0.357636, leaf_value: 1, size: 250
#     └──3, criterion: 0.497689, leaf_value: 0, size: 450
# Tree : 36
# └──1, criterion: 0.471201, size: 700
#     ├──2, criterion: 0.480507, leaf_value: 0, size: 614
#     └──3, criterion: 0.196587, leaf_value: 1, size: 86
# Tree : 37
# └──1, criterion: 0.460554, size: 700
#     ├──2, criterion: 0.11741, leaf_value: 0, size: 34
#     └──3, criterion: 0.451664, leaf_value: 1, size: 666
# Tree : 38
# └──1, criterion: 0.471843, size: 700
#     ├──2, criterion: 0.457193, leaf_value: 1, size: 634
#     └──3, criterion: 0.337748, leaf_value: 0, size: 66
# Tree : 39
# └──1, criterion: 0.480634, size: 700
#     ├──2, criterion: 0.362798, leaf_value: 1, size: 230
#     └──3, criterion: 0.498199, leaf_value: 0, size: 470
# Tree : 40
# └──1, criterion: 0.47888, size: 700
#     ├──2, criterion: 0.485576, leaf_value: 0, size: 637
#     └──3, criterion: 0.126764, leaf_value: 1, size: 63
# Tree : 41
# └──1, criterion: 0.469025, size: 700
#     ├──2, criterion: 0.39757, leaf_value: 0, size: 92
#     └──3, criterion: 0.450921, leaf_value: 1, size: 608
# Tree : 42
# └──1, criterion: 0.47779, size: 700
#     ├──2, criterion: 0.314128, leaf_value: 1, size: 146
#     └──3, criterion: 0.489009, leaf_value: 0, size: 554
# Tree : 43
# └──1, criterion: 0.469588, size: 700
#     ├──2, criterion: 0.126406, leaf_value: 0, size: 34
#     └──3, criterion: 0.462313, leaf_value: 1, size: 666
# Tree : 44
# └──1, criterion: 0.479591, size: 700
#     ├──2, criterion: 0.463676, leaf_value: 1, size: 618
#     └──3, criterion: 0.391617, leaf_value: 0, size: 82
# Tree : 45
# └──1, criterion: 0.486618, size: 700
#     ├──2, criterion: 0.499961, leaf_value: 0, size: 573
#     └──3, criterion: 0.275433, leaf_value: 1, size: 127
# Tree : 46
# └──1, criterion: 0.481975, size: 700
#     ├──2, criterion: 0.487634, leaf_value: 0, size: 637
#     └──3, criterion: 0.14181, leaf_value: 1, size: 63
# Tree : 47
# └──1, criterion: 0.472665, size: 700
#     ├──2, criterion: 0.483539, leaf_value: 0, size: 574
#     └──3, criterion: 0.292329, leaf_value: 1, size: 126
# Tree : 48
# └──1, criterion: 0.463204, size: 700
#     ├──2, criterion: 0.13791, leaf_value: 0, size: 34
#     └──3, criterion: 0.456146, leaf_value: 1, size: 666
# Tree : 49
# └──1, criterion: 0.474239, size: 700
#     ├──2, criterion: 0.452603, leaf_value: 0, size: 141
#     └──3, criterion: 0.451988, leaf_value: 1, size: 559
# PREDICT --- 0.0020322799682617188 seconds ---
# accuracy_score: 0.83
# log_loss: 10.82
# f1_score: 0.63
# (array([0, 1], dtype=int32), array([205,  95]))
# []
# -----------------------------------------
# mode :              regression
# epochs :            5
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         1
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 93.5679 Metric va : 101.676 Residuals (mean) : -508.197
# Epoch : 2     Metric Train : 90.6867 Metric va : 98.9202 Residuals (mean) : -457.378
# Epoch : 3     Metric Train : 88.4611 Metric va : 96.1682 Residuals (mean) : -411.64
# Epoch : 4     Metric Train : 86.1242 Metric va : 94.5949 Residuals (mean) : -370.476
# Epoch : 5     Metric Train : 84.1233 Metric va : 92.273  Residuals (mean) : -333.428
# FIT --- 0.10902619361877441 seconds ---
# PREDICT --- 2.4318695068359375e-05 seconds ---
# [-508.19749172 -457.37774255 -411.63996829 -370.47597146 -333.42837432]
# Print.
# Tree : 0
# └──1, criterion: 95.8068, size: 700
#     ├──2, criterion: 79.9472, leaf_value: -50.5767, size: 466
#     └──3, criterion: 86.3583, leaf_value: 79.0032, size: 234
# Tree : 1
# └──1, criterion: 93.2837, size: 700
#     ├──2, criterion: 76.6137, leaf_value: -86.3799, size: 266
#     └──3, criterion: 81.5431, leaf_value: 42.4038, size: 434
# Tree : 2
# └──1, criterion: 90.4778, size: 700
#     ├──2, criterion: 78.7713, leaf_value: -47.6568, size: 444
#     └──3, criterion: 79.4921, leaf_value: 66.5751, size: 256
# Tree : 3
# └──1, criterion: 88.258, size: 700
#     ├──2, criterion: 74.0077, leaf_value: -46.9349, size: 439
#     └──3, criterion: 81.1795, leaf_value: 64.7497, size: 261
# Tree : 4
# └──1, criterion: 86.0214, size: 700
#     ├──2, criterion: 74.8719, leaf_value: -56.9211, size: 339
#     └──3, criterion: 77.6908, leaf_value: 44.216, size: 361
# 0

# %%
sys.path.append('/home/alexandre/Desktop/lltrees/build')
import lltrees

# %% [markdown]
# # Regression

# %%
X, Y = sklearn.datasets.make_regression(n_samples=1000, n_features=8, n_informative=5, n_targets=1, noise=1, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Tree

# %%
conf ={
    'mode' : 'regression',
    'epochs' : 1,
    'learning_rate' : 1,
    'metric' : 'mae', 
    'max_depth' : 5,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error",
    'verbose' : 1, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()
time.sleep(0.1)

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              regression
# epochs :            1
# learning_rate :     1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# FIT --- 0.07043027877807617 seconds ---
# PREDICT --- 7.43865966796875e-05 seconds ---
# rmse: 56.64
# mae: 43.53
# r2: 0.79

# %%
my_lltree = sklearn.tree.DecisionTreeRegressor(max_depth = 5, criterion ="absolute_error", min_samples_split=2, random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.019928455352783203 seconds ---
# PREDICT --- 0.00015974044799804688 seconds ---
# rmse: 63.68
# mae: 49.35
# r2: 0.74

# %% [markdown]
# ## GBT

# %%
conf ={
    'mode' : 'regression',
    'epochs' : 50,
    'learning_rate' : 0.1,
    'metric' : 'mae',
    'max_depth' : 2,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error", 
    'verbose' : 0, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()
time.sleep(0.1)

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              regression
# epochs :            50
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         2
# min_leaf_size :     2
# verbose :           0
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# FIT --- 3.565692901611328 seconds ---
# PREDICT --- 0.0012500286102294922 seconds ---
# rmse: 36.46
# mae: 26.95
# r2: 0.91

# %%
from sklearn.ensemble import GradientBoostingRegressor
my_lltree = GradientBoostingRegressor(learning_rate = 0.1, n_estimators =50, max_depth = 2, min_samples_leaf=2, min_samples_split=2,
                                 loss = 'absolute_error', criterion = 'squared_error',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.08390688896179199 seconds ---
# PREDICT --- 0.0005669593811035156 seconds ---
# rmse: 52.46
# mae: 38.62
# r2: 0.82

# %% [markdown]
# # Classification

# %%
X, Y = sklearn.datasets.make_classification(n_samples=1000, n_features=8, n_informative=5, n_classes=2, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Tree

# %%
from sklearn.tree import DecisionTreeClassifier
my_lltree = DecisionTreeClassifier(max_depth = 5, min_samples_split=5,
                                 splitter = 'best', criterion = 'gini',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# FIT --- 0.0027418136596679688 seconds ---
# PREDICT --- 0.0001678466796875 seconds ---
# accuracy_score: 0.94
# log_loss: 3.80
# f1_score: 0.90

# %%
conf ={
    'mode' : 'classification',
    'epochs' : 1,
    'learning_rate' : 1,
    'metric' : 'accuracy',
    'max_depth' : 5,
    'min_leaf_size' : 5,
    'criterion' : "gini",  
    'verbose' : 0  
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()
time.sleep(0.5)

start_time = time.time()
my_lltree.fit(X_train, Y_train.astype(np.int32), X_test, Y_test.astype(np.int32))
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              classification
# epochs :            1
# learning_rate :     1
# metric :            accuracy
# criterion :         gini
# max_depth :         5
# min_leaf_size :     5
# verbose :           0
# -----------------------------------------
# Type of Training Data : int32
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0 1
#
#
# FIT --- 0.21864843368530273 seconds ---
# PREDICT --- 0.00021600723266601562 seconds ---
#
# accuracy_score: 0.93
# log_loss: 4.61
# f1_score: 0.87

# %% [markdown]
# ## GBT

# %%
conf ={
    'mode' : 'classification',
    'epochs' : 50,
    'learning_rate' : 0.1,
    'metric' : 'accuracy',
    'max_depth' : 2,
    'min_leaf_size' : 1,
    'criterion' : "gini",  
    'verbose' : 0,  
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()
time.sleep(0.1)

start_time = time.time()
my_lltree.fit(X_train, Y_train.astype(np.int32), X_test, Y_test.astype(np.int32))
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              classification
# epochs :            50
# learning_rate :     0.1
# metric :            accuracy
# criterion :         gini
# max_depth :         2
# min_leaf_size :     1
# verbose :           0
# -----------------------------------------
# FIT --- 10.051023721694946 seconds ---
# PREDICT --- 0.0022597312927246094 seconds ---
# accuracy_score: 0.95
# Type of Training Data : int32
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# log_loss: 3.22
# f1_score: 0.91

# %%
from sklearn.ensemble import GradientBoostingClassifier
my_lltree = GradientBoostingClassifier(learning_rate = 0.1, n_estimators =50, max_depth = 2,
                                 loss = 'log_loss', criterion = 'friedman_mse',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# FIT --- 0.052026987075805664 seconds ---
# PREDICT --- 0.0005605220794677734 seconds ---
# accuracy_score: 0.96
# log_loss: 2.99
# f1_score: 0.92
