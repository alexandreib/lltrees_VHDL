# %%
import time

import numpy as np
import pandas as pd
import sklearn.datasets, sklearn.metrics, sklearn.model_selection, sklearn.tree

import subprocess, sys

# %%
# !cd ../ && make print-SOURCES
# Out:
# SOURCES = cpp/conf.cpp cpp/criterion.cpp cpp/factories.cpp cpp/gbt.cpp cpp/lltrees.cpp cpp/metrics.cpp cpp/node.cpp cpp/tree.cpp cpp/wrapper.cpp

# %%
X, Y = sklearn.datasets.make_classification(n_samples=1000, n_features=8, n_informative=5, n_classes=2, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
np.unique(Y_train, return_counts=True)
# Out:
# (array([0, 1]), array([359, 341]))

# %%
# !cd ../ && make clean
# !cd ../ && make
subprocess.call([sys.executable, "lltrees_python_import_for_debug.py"])
# Out:
# rm -rf build
# mkdir -p build
# g++ -g -o build/conf.o cpp/conf.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/criterion.o cpp/criterion.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/factories.o cpp/factories.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/gbt.o cpp/gbt.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/lltrees.o cpp/lltrees.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/metrics.o cpp/metrics.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/node.o cpp/node.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/tree.o cpp/tree.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/wrapper.o cpp/wrapper.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/lltrees.so build/conf.o build/criterion.o build/factories.o build/gbt.o build/lltrees.o build/metrics.o build/node.o build/tree.o build/wrapper.o -L/usr/lib/python3.10/config-3.10-x86_64-linux-gnu -L/usr/lib/x86_64-linux-gnu  -lcrypt -ldl  -lm -lm  -shared -Wl,-rpath,/usr/lib  -lpython3.10 -lboost_python310 -lboost_numpy310
# -----------------------------------------
# mode :              classification
# epochs :            1
# learning_rate :     1
# metric :            accuracy
# criterion :         gini
# max_depth :         5
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# Type of Training Data : int64
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0
#
#
# Epoch : 1     Metric Train : 1       Metric va : 0.678414 Residuals (mean) : 1
# Print.
# Tree : 0
# └──1, impurity: 0, leaf_value: 0, size: 342
#
# -----------------------------------------
# mode :              regression
# epochs :            1
# learning_rate :     1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     1
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 11.1686 Metric va : 42.484  Residuals (mean) : -2355.95
# -----------------------------------------
# mode :              classification
# epochs :            2
# learning_rate :     0.5
# metric :            accuracy
# criterion :         gini
# max_depth :         2
# min_leaf_size :     1
# verbose :           1
# -----------------------------------------
# Type of Training Data : int64
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0 1
#
#
# Epoch : 1     Metric Train : 0.745714 Metric va : 0.74    Residuals (mean) : 0.745714
#
#
# Epoch : 2     Metric Train : 0.745714 Metric va : 0.74    Residuals (mean) : 0.745714
# Print.
# Tree : 0
# └──1, impurity: 0.379249, size: 700
#     ├──2, impurity: 0.498967, size: 44
#     │   ├──4, impurity: 0.437045, size: 31
#     │   │   ├──8, impurity: 0.30839, size: 21
#     │   │   │   ├──16, impurity: 0.46281, size: 11
#     │   │   │   │   ├──32, impurity: 0.444444, size: 6
#     │   │   │   │   │   ├──64, impurity: 0.444444, leaf_value: 0, size: 3
#     │   │   │   │   │   └──65, impurity: 0, leaf_value: 1, size: 3
#     │   │   │   │   └──33, impurity: 0, leaf_value: 0, size: 5
#     │   │   │   └──17, impurity: 0, leaf_value: 0, size: 10
#     │   │   └──9, impurity: 0.48, size: 10
#     │   │       ├──18, impurity: 0, leaf_value: 1, size: 4
#     │   │       └──19, impurity: 0.444444, size: 6
#     │   │           ├──38, impurity: 0, leaf_value: 0, size: 4
#     │   │           └──39, impurity: 0, leaf_value: 1, size: 2
#     │   └──5, impurity: 0.260355, size: 13
#     │       ├──10, impurity: 0.48, size: 5
#     │       │   ├──20, impurity: 0, leaf_value: 1, size: 3
#     │       │   └──21, impurity: 0, leaf_value: 0, size: 2
#     │       └──11, impurity: 0, leaf_value: 1, size: 8
#     └──3, impurity: 0.364102, size: 656
#         ├──6, impurity: 0.408163, size: 7
#         │   ├──12, impurity: 0, leaf_value: 0, size: 2
#         │   └──13, impurity: 0, leaf_value: 1, size: 5
#         └──7, impurity: 0.358708, size: 649
#             ├──14, impurity: 0.243449, size: 141
#             │   ├──28, impurity: 0.375, size: 4
#             │   │   ├──56, impurity: 0.5, leaf_value: 1, size: 2
#             │   │   └──57, impurity: 0, leaf_value: 1, size: 2
#             │   └���─29, impurity: 0.21738, size: 137
#             │       ├──58, impurity: 0.173006, size: 115
#             │       │   ├──116, impurity: 0.150248, size: 110
#             │       │   │   ├──232, impurity: 0.375, size: 12
#             │       │   │   │   ├──464, impurity: 0.5, size: 6
#             │       │   │   │   │   ├──928, impurity: 0, leaf_value: 0, size: 2
#             │       │   │   │   │   └──929, impurity: 0.375, size: 4
#             │       │   │   │   │       ├──1858, impurity: 0, leaf_value: 1, size: 2
#             │       │   │   │   │       └──1859, impurity: 0.5, leaf_value: 0, size: 2
#             │       │   │   │   └──465, impurity: 0, leaf_value: 0, size: 6
#             │       │   │   └──233, impurity: 0.114952, size: 98
#             │       │   │       ├──466, impurity: 0.0987413, size: 96
#             │       │   │       │   ├──932, impurity: 0.224766, size: 31
#             │       │   │       │   │   ├──1864, impurity: 0.137174, size: 27
#             │       │   │       │   │   │   ├──3728, impurity: 0.408163, size: 7
#             │       │   │       │   │   │   │   ├──7456, impurity: 0, leaf_value: 0, size: 4
#             │       │   │       │   │   │   │   └──7457, impurity: 0.444444, leaf_value: 1, size: 3
#             │       │   │       │   │   │   └──3729, impurity: 0, leaf_value: 0, size: 20
#             │       │   │       │   │   └──1865, impurity: 0.5, size: 4
#             │       │   │       │   │       ├──3730, impurity: 0, leaf_value: 0, size: 2
#             │       │   │       │   │       └──3731, impurity: 0, leaf_value: 1, size: 2
#             │       │   │       │   └──933, impurity: 0.0302959, size: 65
#             │       │   │       │       ├──1866, impurity: 0, leaf_value: 0, size: 61
#             │       │   │       │       └──1867, impurity: 0.375, size: 4
#             │       │   │       │           ├──3734, impurity: 0, leaf_value: 0, size: 2
#             │       │   │       │           └──3735, impurity: 0.5, leaf_value: 1, size: 2
#             │       │   │       └──467, impurity: 0.5, leaf_value: 0, size: 2
#             │       │   └──117, impurity: 0.48, size: 5
#             │       │       ├──234, impurity: 0, leaf_value: 0, size: 2
#             │       │       └──235, impurity: 0.444444, leaf_value: 1, size: 3
#             │       └──59, impurity: 0.396694, size: 22
#             │           ├──118, impurity: 0.152778, size: 12
#             │           │   ├──236, impurity: 0, leaf_value: 0, size: 10
#             │           │   └──237, impurity: 0.5, leaf_value: 1, size: 2
#             │           └──119, impurity: 0.5, size: 10
#             │               ├──238, impurity: 0, leaf_value: 1, size: 3
#             │               └──239, impurity: 0.408163, size: 7
#             │                   ├──478, impurity: 0, leaf_value: 0, size: 3
#             │                   └──479, impurity: 0.5, size: 4
#             │                       ├──958, impurity: 0, leaf_value: 1, size: 2
#             │                       └──959, impurity: 0, leaf_value: 0, size: 2
#             └──15, impurity: 0.384649, size: 508
#                 ├──30, impurity: 0.455, size: 20
#                 │   ├──60, impurity: 0, leaf_value: 0, size: 3
#                 │   └──61, impurity: 0.359862, size: 17
#                 │       ├──122, impurity: 0.142012, size: 13
#                 │       │   ├──244, impurity: 0, leaf_value: 1, size: 11
#                 │       │   └──245, impurity: 0.5, leaf_value: 1, size: 2
#                 │       └──123, impurity: 0.375, size: 4
#                 │           ├──246, impurity: 0.5, leaf_value: 1, size: 2
#                 │           └──247, impurity: 0, leaf_value: 0, size: 2
#                 └──31, impurity: 0.368777, size: 488
#                     ├──62, impurity: 0.495868, size: 22
#                     │   ├──124, impurity: 0.375, size: 8
#                     │   │   ├──248, impurity: 0.444444, leaf_value: 1, size: 3
#                     │   │   └──249, impurity: 0, leaf_value: 0, size: 5
#                     │   └──125, impurity: 0.408163, size: 14
#                     │       ├──250, impurity: 0.489796, size: 7
#                     │       │   ├──500, impurity: 0, leaf_value: 1, size: 3
#                     │       │   └──501, impurity: 0, leaf_value: 0, size: 4
#                     │       └──251, impurity: 0, leaf_value: 1, size: 7
#                     └──63, impurity: 0.353783, size: 466
#                         ├──126, impurity: 0.302973, size: 274
#                         │   ├──252, impurity: 0.382738, size: 159
#                         │   │   ├──504, impurity: 0.35503, size: 143
#                         │   │   │   ├──1008, impurity: 0.495868, size: 11
#                         │   │   │   │   ├──2016, impurity: 0, leaf_value: 1, size: 4
#                         │   │   │   │   └──2017, impurity: 0.408163, size: 7
#                         │   │   │   │       ├──4034, impurity: 0, leaf_value: 0, size: 3
#                         │   │   │   │       └──4035, impurity: 0.5, size: 4
#                         │   │   │   │           ├──8070, impurity: 0, leaf_value: 0, size: 2
#                         │   │   │   │           └──8071, impurity: 0, leaf_value: 1, size: 2
#                         │   │   │   └──1009, impurity: 0.325413, size: 132
#                         │   │   │       ├──2018, impurity: 0.281728, size: 112
#                         │   │   │       │   ├──4036, impurity: 0.152778, size: 60
#                         │   │   │       │   │   ├──8072, impurity: 0.0726237, size: 53
#                         │   │   │       │   │   │   ├──16144, impurity: 0.375, size: 8
#                         │   │   │       │   │   │   │   ├──32288, impurity: 0, leaf_value: 0, size: 5
#                         │   │   │       │   │   │   │   └──32289, impurity: 0.444444, leaf_value: 1, size: 3
#                         │   │   │       │   │   │   └──16145, impurity: 0, leaf_value: 0, size: 45
#                         │   │   │       │   │   └──8073, impurity: 0.489796, size: 7
#                         │   │   │       │   │       ├──16146, impurity: 0, leaf_value: 1, size: 3
#                         │   │   │       │   │       └──16147, impurity: 0, leaf_value: 0, size: 4
#                         │   │   │       │   └──4037, impurity: 0.393491, size: 52
#                         │   │   │       │       ├──8074, impurity: 0, leaf_value: 1, size: 3
#                         │   │   │       │       └──8075, impurity: 0.348188, size: 49
#                         │   │   │       │           ├──16150, impurity: 0.497778, size: 15
#                         │   │   │       │           │   ├──32300, impurity: 0.277778, size: 6
#                         │   │   │       │           │   │   ├──64600, impurity: 0, leaf_value: 1, size: 4
#                         │   │   │       │           │   │   └──64601, impurity: 0.5, leaf_value: 1, size: 2
#                         │   │   │       │           │   └──32301, impurity: 0.345679, size: 9
#                         │   │   │       │           │       ├──64602, impurity: 0.5, size: 4
#                         │   │   │       │           │       │   ├──129204, impurity: 0, leaf_value: 0, size: 2
#                         │   │   │       │           │       │   └──129205, impurity: 0, leaf_value: 1, size: 2
#                         │   │   │       │           │       └──64603, impurity: 0, leaf_value: 0, size: 5
#                         │   │   │       │           └──16151, impurity: 0.207612, size: 34
#                         │   │   │       │               ├──32302, impurity: 0.345679, size: 18
#                         │   │   │       │               │   ├──64604, impurity: 0.124444, size: 15
#                         │   │   │       │               │   │   ├──129208, impurity: 0, leaf_value: 0, size: 13
#                         │   │   │       │               │   │   └──129209, impurity: 0.5, leaf_value: 0, size: 2
#                         │   │   │       │               │   └──64605, impurity: 0, leaf_value: 1, size: 3
#                         │   │   │       │               └──32303, impurity: 0, leaf_value: 0, size: 16
#                         │   │   │       └──2019, impurity: 0.48, size: 20
#                         │   │   │           ├──4038, impurity: 0.32, size: 10
#                         │   │   │           │   ├──8076, impurity: 0.444444, leaf_value: 1, size: 3
#                         │   │   │           │   └──8077, impurity: 0, leaf_value: 0, size: 7
#                         │   │   │           └──4039, impurity: 0.48, size: 10
#                         │   │   │               ├──8078, impurity: 0, leaf_value: 1, size: 4
#                         │   │   │               └──8079, impurity: 0.444444, size: 6
#                         │   │   │                   ├──16158, impurity: 0.444444, leaf_value: 1, size: 3
#                         │   │   │                   └──16159, impurity: 0, leaf_value: 0, size: 3
#                         │   │   └──505, impurity: 0.5, size: 16
#                         │   │       ├──1010, impurity: 0.32, size: 5
#                         │   │       │   ├──2020, impurity: 0, leaf_value: 0, size: 3
#                         │   │       │   └──2021, impurity: 0.5, leaf_value: 0, size: 2
#                         │   │       └──1011, impurity: 0.46281, size: 11
#                         │   │           ├──2022, impurity: 0, leaf_value: 1, size: 5
#                         │   │           └──2023, impurity: 0.444444, size: 6
#                         │   │               ├──4046, impurity: 0, leaf_value: 1, size: 2
#                         │   │               └──4047, impurity: 0, leaf_value: 0, size: 4
#                         │   └──253, impurity: 0.15879, size: 115
#                         │       ├──506, impurity: 0.133755, size: 111
#                         │       │   ├──1012, impurity: 0.105861, size: 107
#                         │       │   │   ├──2024, impurity: 0.0302959, size: 65
#                         │       │   │   │   ├──4048, impurity: 0.5, leaf_value: 0, size: 2
#                         │       │   │   │   └──4049, impurity: 0, leaf_value: 0, size: 63
#                         │       │   │   └──2025, impurity: 0.209751, size: 42
#                         │       │   │       ├──4050, impurity: 0.5, size: 4
#                         │       │   │       │   ├──8100, impurity: 0, leaf_value: 1, size: 2
#                         │       │   │       │   └──8101, impurity: 0, leaf_value: 0, size: 2
#                         │       │   │       └──4051, impurity: 0.145429, size: 38
#                         │       │   │           ├──8102, impurity: 0.0665874, size: 29
#                         │       │   │           │   ├──16204, impurity: 0, leaf_value: 0, size: 25
#                         │       │   │           │   └──16205, impurity: 0.375, size: 4
#                         │       │   │           │       ├──32410, impurity: 0, leaf_value: 0, size: 2
#                         │       │   │           │       └──32411, impurity: 0.5, leaf_value: 1, size: 2
#                         │       │   │           └──8103, impurity: 0.345679, size: 9
#                         │       │   │               ├──16206, impurity: 0.5, size: 4
#                         │       │   │               │   ├──32412, impurity: 0, leaf_value: 0, size: 2
#                         │       │   │               │   └──32413, impurity: 0, leaf_value: 1, size: 2
#                         │       │   │               └──16207, impurity: 0, leaf_value: 0, size: 5
#                         │       │   └──1013, impurity: 0.5, size: 4
#                         │       │       ├──2026, impurity: 0, leaf_value: 1, size: 2
#                         │       │       └──2027, impurity: 0, leaf_value: 0, size: 2
#                         │       └──507, impurity: 0.5, size: 4
#                         │           ├──1014, impurity: 0, leaf_value: 1, size: 2
#                         │           └──1015, impurity: 0, leaf_value: 0, size: 2
#                         └──127, impurity: 0.413194, size: 192
#                             ├──254, impurity: 0.444444, size: 6
#                             │   ├──508, impurity: 0, leaf_value: 1, size: 4
#                             │   └──509, impurity: 0, leaf_value: 0, size: 2
#                             └──255, impurity: 0.402821, size: 186
#                                 ├──510, impurity: 0.430006, size: 147
#                                 │   ├──1020, impurity: 0.422735, size: 145
#                                 │   │   ├──2040, impurity: 0.449732, size: 123
#                                 │   │   │   ├──4080, impurity: 0, leaf_value: 1, size: 2
#                                 │   │   │   └──4081, impurity: 0.442593, size: 121
#                                 │   │   │       ├──8162, impurity: 0.463757, size: 104
#                                 │   │   │       │   ├──16324, impurity: 0.444444, size: 96
#                                 │   │   │       │   │   ├──32648, impurity: 0.293367, size: 28
#                                 │   │   │       │   │   │   ├──65296, impurity: 0.104938, size: 18
#                                 │   │   │       │   │   │   │   ├──130592, impurity: 0.5, leaf_value: 1, size: 2
#                                 │   │   │       │   │   │   │   └──130593, impurity: 0, leaf_value: 0, size: 16
#                                 │   │   │       │   │   │   └──65297, impurity: 0.48, size: 10
#                                 │   │   │       │   │   │       ├──130594, impurity: 0, leaf_value: 0, size: 4
#                                 │   │   │       │   │   │       └──130595, impurity: 0.444444, size: 6
#                                 │   │   │       │   │   │           ├──261190, impurity: 0.444444, leaf_value: 0, size: 3
#                                 │   │   │       │   │   │           └──261191, impurity: 0, leaf_value: 1, size: 3
#                                 │   │   │       │   │   └──32649, impurity: 0.478806, size: 68
#                                 │   │   │       │   │       ├──65298, impurity: 0, leaf_value: 1, size: 3
#                                 │   │   │       │   │       └──65299, impurity: 0.465799, size: 65
#                                 │   │   │       │   │           ├──130598, impurity: 0.426036, size: 52
#                                 │   │   │       │   │           │   ├──261196, impurity: 0.368828, size: 41
#                                 │   │   │       │   │           │   │   ├──522392, impurity: 0.306793, size: 37
#                                 │   │   │       │   │           │   │   │   ├──1044784, impurity: 0.432133, size: 19
#                                 │   │   │       │   │           │   │   │   │   ├──2089568, impurity: 0, leaf_value: 0, size: 5
#                                 │   │   │       │   │           │   │   │   │   └──2089569, impurity: 0.489796, size: 14
#                                 │   │   │       │   │           │   │   │   │       ├──4179138, impurity: 0.408163, size: 7
#                                 │   │   │       │   │           │   │   │   │       │   ├──8358276, impurity: 0, leaf_value: 1, size: 2
#                                 │   │   │       │   │           │   │   │   │       │   └──8358277, impurity: 0.48, size: 5
#                                 │   │   │       │   │           │   │   │   │       │       ├──16716554, impurity: 0.5, leaf_value: 1, size: 2
#                                 │   │   │       │   │           │   │   │   │       │       └──16716555, impurity: 0.444444, leaf_value: 1, size: 3
#                                 │   │   │       │   │           │   │   │   │       └──4179139, impurity: 0.244898, size: 7
#                                 │   │   │       │   │           │   │   │   │           ├──8358278, impurity: 0.5, leaf_value: 0, size: 2
#                                 │   │   │       │   │           │   │   │   │           └──8358279, impurity: 0, leaf_value: 0, size: 5
#                                 │   │   │       │   │           │   │   │   └──1044785, impurity: 0.104938, size: 18
#                                 │   │   │       │   │           │   │   │       ├──2089570, impurity: 0.5, leaf_value: 1, size: 2
#                                 │   │   │       │   │           │   │   │       └──2089571, impurity: 0, leaf_value: 0, size: 16
#                                 │   │   │       │   │           │   │   └──522393, impurity: 0.375, size: 4
#                                 │   │   │       │   │           │   │       ├──1044786, impurity: 0, leaf_value: 1, size: 2
#                                 │   │   │       │   │           │   │       └──1044787, impurity: 0.5, leaf_value: 0, size: 2
#                                 │   │   │       │   │           │   └──261197, impurity: 0.495868, size: 11
#                                 │   │   │       │   │           │       ├──522394, impurity: 0, leaf_value: 1, size: 4
#                                 │   │   │       │   │           │       └──522395, impurity: 0.408163, size: 7
#                                 │   │   │       │   │           │           ├──1044790, impurity: 0, leaf_value: 0, size: 5
#                                 │   │   │       │   │           │           └──1044791, impurity: 0, leaf_value: 1, size: 2
#                                 │   │   │       │   │           └──130599, impurity: 0.473373, size: 13
#                                 │   │   │       │   │               ├──261198, impurity: 0.444444, size: 6
#                                 │   │   │       │   │               │   ├──522396, impurity: 0, leaf_value: 0, size: 4
#                                 │   │   │       │   │               │   └──522397, impurity: 0, leaf_value: 1, size: 2
#                                 │   │   │       │   │               └──261199, impurity: 0.244898, size: 7
#                                 │   │   │       │   │                   ├──522398, impurity: 0.5, leaf_value: 0, size: 2
#                                 │   │   │       │   │                   └──522399, impurity: 0, leaf_value: 1, size: 5
#                                 │   │   │       │   └──16325, impurity: 0.375, size: 8
#                                 │   │   │       │       ├──32650, impurity: 0, leaf_value: 1, size: 6
#                                 │   │   │       │       └──32651, impurity: 0, leaf_value: 0, size: 2
#                                 │   │   │       └──8163, impurity: 0.207612, size: 17
#                                 │   │   │           ├──16326, impurity: 0.5, leaf_value: 0, size: 4
#                                 │   │   │           └──16327, impurity: 0, leaf_value: 0, size: 13
#                                 │   │   └──2041, impurity: 0.165289, size: 22
#                                 │   │       ├──4082, impurity: 0, leaf_value: 0, size: 16
#                                 │   │       └──4083, impurity: 0.444444, size: 6
#                                 │   │           ├──8166, impurity: 0.444444, leaf_value: 1, size: 3
#                                 │   │           └──8167, impurity: 0, leaf_value: 0, size: 3
#                                 │   └──1021, impurity: 0, leaf_value: 1, size: 2
#                                 └──511, impurity: 0.260355, size: 39
#                                     ├──1022, impurity: 0.0739645, size: 26
#                                     │   ├──2044, impurity: 0.5, leaf_value: 1, size: 2
#                                     │   └──2045, impurity: 0, leaf_value: 0, size: 24
#                                     └──1023, impurity: 0.473373, size: 13
#                                         ├──2046, impurity: 0, leaf_value: 1, size: 2
#                                         └──2047, impurity: 0.396694, size: 11
#                                             ├──4094, impurity: 0.489796, size: 7
#                                             │   ├──8188, impurity: 0, leaf_value: 0, size: 3
#                                             │   └──8189, impurity: 0.375, size: 4
#                                             │       ├──16378, impurity: 0, leaf_value: 1, size: 2
#                                             │       └──16379, impurity: 0.5, leaf_value: 0, size: 2
#                                             └──4095, impurity: 0, leaf_value: 0, size: 4
# Tree : 1
# └──1, impurity: 0.383512, size: 700
#     ├──2, impurity: 0.499542, size: 44
#     │   ├──4, impurity: 0.446513, size: 31
#     │   │   ├──8, impurity: 0, leaf_value: 0, size: 8
#     │   │   └──9, impurity: 0.495057, size: 23
#     │   │       ├──18, impurity: 0.404711, size: 10
#     │   │       │   ├──36, impurity: 0.498066, size: 5
#     │   │       │   │   ├──72, impurity: 0, leaf_value: 1, size: 2
#     │   │       │   │   └──73, impurity: 0, leaf_value: 0, size: 3
#     │   │       │   └──37, impurity: 0, leaf_value: 1, size: 5
#     │   │       └──19, impurity: 0.35503, size: 13
#     │   │           ├──38, impurity: 0.489796, size: 7
#     │   │           │   ├──76, impurity: 0, leaf_value: 0, size: 4
#     │   │           │   └──77, impurity: 0, leaf_value: 1, size: 3
#     │   │           └──39, impurity: 0, leaf_value: 0, size: 6
#     │   └──5, impurity: 0.260355, size: 13
#     │       ├──10, impurity: 0.48, size: 5
#     │       │   ├──20, impurity: 0, leaf_value: 1, size: 3
#     │       │   └──21, impurity: 0, leaf_value: 0, size: 2
#     │       └──11, impurity: 0, leaf_value: 1, size: 8
#     └──3, impurity: 0.368646, size: 656
#         ├──6, impurity: 0.408163, size: 7
#         │   ├──12, impurity: 0, leaf_value: 0, size: 2
#         │   └──13, impurity: 0, leaf_value: 1, size: 5
#         └──7, impurity: 0.363551, size: 649
#             ├──14, impurity: 0.333, size: 493
#             │   ├──28, impurity: 0.23442, size: 174
#             │   │   ├──56, impurity: 0.281787, size: 138
#             │   │   │   ├──112, impurity: 0.407264, size: 46
#             │   │   │   │   ├──224, impurity: 0.378505, size: 44
#             │   │   │   │   │   ├──448, impurity: 0.248684, size: 30
#             │   │   │   │   │   │   ├──896, impurity: 0, leaf_value: 0, size: 16
#             │   │   │   │   │   │   └──897, impurity: 0.423081, size: 14
#             │   │   │   │   │   │       ├──1794, impurity: 0, leaf_value: 1, size: 3
#             │   │   │   │   │   │       └──1795, impurity: 0.232191, size: 11
#             │   │   │   │   │   │           ├──3590, impurity: 0, leaf_value: 0, size: 9
#             │   │   │   │   │   │           └──3591, impurity: 0.470007, leaf_value: 0, size: 2
#             │   │   │   │   │   └──449, impurity: 0.5, size: 14
#             │   │   │   │   │       ├──898, impurity: 0.32, size: 5
#             │   │   │   │   │       │   ├──1796, impurity: 0, leaf_value: 1, size: 3
#             │   │   │   │   │       │   └──1797, impurity: 0.5, leaf_value: 0, size: 2
#             │   │   │   │   │       └──899, impurity: 0.444444, size: 9
#             │   │   │   │   │           ├──1798, impurity: 0.244898, size: 7
#             │   │   │   │   │           │   ├──3596, impurity: 0, leaf_value: 0, size: 5
#             │   │   │   │   │           │   └──3597, impurity: 0.5, leaf_value: 0, size: 2
#             │   │   │   │   │           └──1799, impurity: 0, leaf_value: 1, size: 2
#             │   │   │   │   └──225, impurity: 0, leaf_value: 1, size: 2
#             │   │   │   └──113, impurity: 0.198609, size: 92
#             │   │   │       ├──226, impurity: 0.428581, size: 13
#             │   │   │       │   ├──452, impurity: 0.325472, size: 11
#             │   │   │       │   │   ├──904, impurity: 0.490263, size: 4
#             │   │   │       │   │   │   ├──1808, impurity: 0, leaf_value: 1, size: 2
#             │   │   │       │   │   │   └──1809, impurity: 0, leaf_value: 0, size: 2
#             │   │   │       │   │   └──905, impurity: 0, leaf_value: 0, size: 7
#             │   │   │       │   └──453, impurity: 0, leaf_value: 1, size: 2
#             │   │   │       └──227, impurity: 0.138278, size: 79
#             │   │   │           ├──454, impurity: 0.0352939, size: 55
#             │   │   │           │   ├──908, impurity: 0.5, leaf_value: 1, size: 2
#             │   │   │           │   └──909, impurity: 0, leaf_value: 0, size: 53
#             │   │   │           └──455, impurity: 0.323404, size: 24
#             │   │   │               ├──910, impurity: 0, leaf_value: 1, size: 3
#             │   │   │               └──911, impurity: 0.167699, size: 21
#             │   │   │                   ├──1822, impurity: 0.5, leaf_value: 1, size: 2
#             │   │   │                   └──1823, impurity: 0.0966074, size: 19
#             │   │   │                       ├──3646, impurity: 0.255566, size: 6
#             │   │   │                       │   ├──7292, impurity: 0, leaf_value: 0, size: 4
#             │   │   │                       │   └──7293, impurity: 0.470007, leaf_value: 1, size: 2
#             │   │   │                       └──3647, impurity: 0, leaf_value: 0, size: 13
#             │   │   └──57, impurity: 0, leaf_value: 0, size: 36
#             │   └──29, impurity: 0.377149, size: 319
#             │       ├──58, impurity: 0, leaf_value: 1, size: 2
#             │       └──59, impurity: 0.372569, size: 317
#             │           ├──118, impurity: 0.244112, size: 76
#             │           │   ├──236, impurity: 0.194464, size: 72
#             │           │   │   ├──472, impurity: 0.158173, size: 68
#             │           │   │   │   ├──944, impurity: 0.342977, size: 13
#             │           │   │   │   │   ├──1888, impurity: 0, leaf_value: 0, size: 10
#             │           │   │   │   │   └──1889, impurity: 0, leaf_value: 1, size: 3
#             │           │   │   │   └──945, impurity: 0.102007, size: 55
#             │           │   │   │       ├──1890, impurity: 0.5, leaf_value: 1, size: 2
#             │           │   │   │       └──1891, impurity: 0.0717796, size: 53
#             │           │   │   │           ├──3782, impurity: 0.0416478, size: 47
#             │           │   │   │           │   ├──7564, impurity: 0.375, size: 4
#             │           │   │   │           │   │   ├──15128, impurity: 0, leaf_value: 0, size: 2
#             │           │   │   │           │   │   └──15129, impurity: 0.5, leaf_value: 1, size: 2
#             │           │   │   │           │   └──7565, impurity: 0, leaf_value: 0, size: 43
#             │           │   │   │           └──3783, impurity: 0.255566, size: 6
#             │           │   │   │               ├──7566, impurity: 0, leaf_value: 0, size: 4
#             │           │   │   │               └──7567, impurity: 0.470007, leaf_value: 1, size: 2
#             │           │   │   └──473, impurity: 0.5, size: 4
#             │           │   │       ├──946, impurity: 0, leaf_value: 0, size: 2
#             │           │   │       └──947, impurity: 0, leaf_value: 1, size: 2
#             │           │   └──237, impurity: 0.375, size: 4
#             │           │       ├──474, impurity: 0.5, leaf_value: 0, size: 2
#             │           │       └──475, impurity: 0, leaf_value: 1, size: 2
#             │           └──119, impurity: 0.40338, size: 241
#             │               ├──238, impurity: 0.464267, size: 13
#             │               │   ├──476, impurity: 0, leaf_value: 1, size: 7
#             │               │   └──477, impurity: 0.372967, size: 6
#             │               │       ├──954, impurity: 0.470007, leaf_value: 0, size: 2
#             │               │       └──955, impurity: 0, leaf_value: 0, size: 4
#             │               └──239, impurity: 0.384554, size: 228
#             │                   ├──478, impurity: 0.330758, size: 141
#             │                   │   ├──956, impurity: 0.410467, size: 81
#             │                   │   │   ├──1912, impurity: 0.267562, size: 44
#             │                   │   │   │   ├──3824, impurity: 0.120708, size: 31
#             │                   │   │   │   │   ├──7648, impurity: 0.0665874, size: 29
#             │                   │   │   │   │   │   ├──15296, impurity: 0.444444, leaf_value: 0, size: 3
#             │                   │   │   │   │   │   └──15297, impurity: 0, leaf_value: 0, size: 26
#             │                   │   │   │   │   └──7649, impurity: 0.5, leaf_value: 0, size: 2
#             │                   │   │   │   └──3825, impurity: 0.473373, size: 13
#             │                   │   │   │       ├──7650, impurity: 0, leaf_value: 1, size: 2
#             │                   │   │   │       └──7651, impurity: 0.396694, size: 11
#             │                   │   │   │           ├──15302, impurity: 0, leaf_value: 0, size: 4
#             │                   │   │   │           └──15303, impurity: 0.489796, size: 7
#             │                   │   │   │               ├──30606, impurity: 0, leaf_value: 1, size: 3
#             │                   │   │   │               └──30607, impurity: 0, leaf_value: 0, size: 4
#             │                   │   │   └──1913, impurity: 0.490149, size: 37
#             │                   │   │       ├──3826, impurity: 0.467168, size: 24
#             │                   │   │       │   ├──7652, impurity: 0.420646, size: 6
#             │                   │   │       │   │   ├──15304, impurity: 0.495366, leaf_value: 1, size: 3
#             │                   │   │       │   │   └──15305, impurity: 0, leaf_value: 0, size: 3
#             │                   │   │       │   └──7653, impurity: 0.383936, size: 18
#             │                   │   │       │       ├──15306, impurity: 0.170179, size: 10
#             │                   │   │       │       │   ├──30612, impurity: 0, leaf_value: 1, size: 8
#             │                   │   │       │       │   └──30613, impurity: 0.5, leaf_value: 0, size: 2
#             │                   │   │       │       └──15307, impurity: 0.497187, size: 8
#             │                   │   │       │           ├──30614, impurity: 0.420646, size: 6
#             │                   │   │       │           │   ├──61228, impurity: 0.444444, leaf_value: 0, size: 3
#             │                   │   │       │           │   └──61229, impurity: 0, leaf_value: 1, size: 3
#             │                   │   │       │           └──30615, impurity: 0, leaf_value: 0, size: 2
#             │                   │   │       └──3827, impurity: 0.130101, size: 13
#             │                   │   │           ├──7654, impurity: 0.337679, size: 4
#             │                   │   │           │   ├──15308, impurity: 0, leaf_value: 0, size: 2
#             │                   │   │           │   └──15309, impurity: 0.470007, leaf_value: 1, size: 2
#             │                   │   │           └──7655, impurity: 0, leaf_value: 0, size: 9
#             │                   │   └──957, impurity: 0.178286, size: 60
#             │                   │       ├──1914, impurity: 0.133426, size: 55
#             │                   │       │   ├──3828, impurity: 0.5, leaf_value: 1, size: 2
#             │                   │       │   └──3829, impurity: 0.105585, size: 53
#             │                   │       │       ├──7658, impurity: 0.345679, size: 9
#             │                   │       │       │   ├──15316, impurity: 0, leaf_value: 0, size: 7
#             │                   │       │       │   └──15317, impurity: 0, leaf_value: 1, size: 2
#             │                   │       │       └──7659, impurity: 0.0437909, size: 44
#             │                   │       │           ├──15318, impurity: 0, leaf_value: 0, size: 29
#             │                   │       │           └──15319, impurity: 0.119639, size: 15
#             │                   │       │               ├──30638, impurity: 0.5, leaf_value: 0, size: 2
#             │                   │       │               └──30639, impurity: 0, leaf_value: 0, size: 13
#             │                   │       └──1915, impurity: 0.48, size: 5
#             │                   │           ├──3830, impurity: 0, leaf_value: 1, size: 2
#             │                   │           └──3831, impurity: 0, leaf_value: 0, size: 3
#             │                   └──479, impurity: 0.449101, size: 87
#             │                       ├──958, impurity: 0.338182, size: 7
#             │                       │   ├──1916, impurity: 0.470007, leaf_value: 0, size: 2
#             │                       │   └──1917, impurity: 0, leaf_value: 1, size: 5
#             │                       └──959, impurity: 0.419741, size: 80
#             │                           ├──1918, impurity: 0.476768, size: 7
#             │                           │   ├──3836, impurity: 0.291382, size: 5
#             │                           │   │   ├──7672, impurity: 0.470007, leaf_value: 0, size: 2
#             │                           │   │   └──7673, impurity: 0, leaf_value: 1, size: 3
#             │                           │   └──3837, impurity: 0, leaf_value: 0, size: 2
#             │                           └──1919, impurity: 0.392818, size: 73
#             │                               ├──3838, impurity: 0.161186, size: 18
#             │                               │   ├──7676, impurity: 0.470007, leaf_value: 0, size: 2
#             │                               │   └──7677, impurity: 0, leaf_value: 0, size: 16
#             │                               └──3839, impurity: 0.440474, size: 55
#             │                                   ├──7678, impurity: 0.396868, size: 50
#             │                                   │   ├──15356, impurity: 0, leaf_value: 1, size: 3
#             │                                   │   └──15357, impurity: 0.351766, size: 47
#             │                                   │       ├──30714, impurity: 0.482758, size: 19
#             │                                   │       │   ├──61428, impurity: 0.396998, size: 14
#             │                                   │       │   │   ├──122856, impurity: 0, leaf_value: 1, size: 2
#             │                                   │       │   │   └──122857, impurity: 0.266234, size: 12
#             │                                   │       │   │       ├──245714, impurity: 0, leaf_value: 0, size: 7
#             │                                   │       │   │       └──245715, impurity: 0.48, size: 5
#             │                                   │       │   │           ├──491430, impurity: 0, leaf_value: 0, size: 2
#             │                                   │       │   │           └──491431, impurity: 0.444444, leaf_value: 1, size: 3
#             │                                   │       │   └──61429, impurity: 0.32, size: 5
#             │                                   │       │       ├──122858, impurity: 0.5, leaf_value: 0, size: 2
#             │                                   │       │       └──122859, impurity: 0, leaf_value: 1, size: 3
#             │                                   │       └──30715, impurity: 0.187502, size: 28
#             │                                   │           ├──61430, impurity: 0, leaf_value: 0, size: 14
#             │                                   │           └──61431, impurity: 0.325709, size: 14
#             │                                   │               ├──122862, impurity: 0.170179, size: 10
#             │                                   │               │   ├──245724, impurity: 0.470007, leaf_value: 0, size: 2
#             │                                   │               │   └──245725, impurity: 0, leaf_value: 0, size: 8
#             │                                   │               └──122863, impurity: 0.5, size: 4
#             │                                   │                   ├──245726, impurity: 0, leaf_value: 1, size: 2
#             │                                   │                   └──245727, impurity: 0, leaf_value: 0, size: 2
#             │                                   └──7679, impurity: 0.291382, size: 5
#             │                                       ├──15358, impurity: 0, leaf_value: 1, size: 3
#             │                                       └──15359, impurity: 0.470007, leaf_value: 1, size: 2
#             └──15, impurity: 0.439651, size: 156
#                 ├──30, impurity: 0.480376, size: 112
#                 │   ├──60, impurity: 0, leaf_value: 1, size: 6
#                 │   └──61, impurity: 0.46507, size: 106
#                 │       ├──122, impurity: 0.30756, size: 39
#                 │       │   ├──244, impurity: 0.187502, size: 28
#                 │       │   │   ├──488, impurity: 0.0749364, size: 25
#                 │       │   │   │   ├──976, impurity: 0.444444, leaf_value: 0, size: 3
#                 │       │   │   │   └──977, impurity: 0, leaf_value: 0, size: 22
#                 │       │   │   └──489, impurity: 0.444444, leaf_value: 1, size: 3
#                 │       │   └──245, impurity: 0.479629, size: 11
#                 │       │       ├──490, impurity: 0.337679, size: 4
#                 │       │       │   ├──980, impurity: 0.470007, leaf_value: 0, size: 2
#                 │       │       │   └──981, impurity: 0, leaf_value: 1, size: 2
#                 │       │       └──491, impurity: 0.244898, size: 7
#                 │       │           ├──982, impurity: 0.5, leaf_value: 0, size: 2
#                 │       │           └──983, impurity: 0, leaf_value: 0, size: 5
#                 │       └──123, impurity: 0.498531, size: 67
#                 │           ├──246, impurity: 0.472817, size: 30
#                 │           │   ├──492, impurity: 0.300387, size: 15
#                 │           │   │   ├──984, impurity: 0, leaf_value: 0, size: 2
#                 │           │   │   └──985, impurity: 0.130101, size: 13
#                 │           │   │       ├──1970, impurity: 0, leaf_value: 1, size: 11
#                 │           │   │       └──1971, impurity: 0.470007, leaf_value: 0, size: 2
#                 │           │   └──493, impurity: 0.48, size: 15
#                 │           │       ├──986, impurity: 0, leaf_value: 0, size: 4
#                 │           │       └──987, impurity: 0.495868, size: 11
#                 │           │           ├──1974, impurity: 0.408163, size: 7
#                 │           │           │   ├──3948, impurity: 0, leaf_value: 0, size: 4
#                 │           │           │   └──3949, impurity: 0.444444, leaf_value: 1, size: 3
#                 │           │           └──1975, impurity: 0, leaf_value: 1, size: 4
#                 │           └──247, impurity: 0.455807, size: 37
#                 │               ├──494, impurity: 0.340265, size: 23
#                 │               │   ├──988, impurity: 0.188366, size: 19
#                 │               │   │   ├──1976, impurity: 0.48, size: 5
#                 │               │   │   │   ├──3952, impurity: 0, leaf_value: 0, size: 3
#                 │               │   │   │   └──3953, impurity: 0, leaf_value: 1, size: 2
#                 │               │   │   └──1977, impurity: 0, leaf_value: 0, size: 14
#                 │               │   └──989, impurity: 0.375, size: 4
#                 │               │       ├──1978, impurity: 0, leaf_value: 1, size: 2
#                 │               │       └──1979, impurity: 0.5, leaf_value: 0, size: 2
#                 │               └──495, impurity: 0.489796, size: 14
#                 │                   ├──990, impurity: 0.345679, size: 9
#                 │                   │   ├──1980, impurity: 0.5, size: 4
#                 │                   │   │   ├──3960, impurity: 0, leaf_value: 1, size: 2
#                 │                   │   │   └──3961, impurity: 0, leaf_value: 0, size: 2
#                 │                   │   └──1981, impurity: 0, leaf_value: 1, size: 5
#                 │                   └──991, impurity: 0.32, size: 5
#                 │                       ├──1982, impurity: 0.5, leaf_value: 0, size: 2
#                 │                       └──1983, impurity: 0, leaf_value: 0, size: 3
#                 └──31, impurity: 0.244662, size: 44
#                     ├──62, impurity: 0.14793, size: 36
#                     │   ├──124, impurity: 0.476768, size: 7
#                     │   │   ├──248, impurity: 0, leaf_value: 1, size: 3
#                     │   │   └──249, impurity: 0, leaf_value: 0, size: 4
#                     │   └──125, impurity: 0, leaf_value: 0, size: 29
#                     └──63, impurity: 0.476863, size: 8
#                         ├──126, impurity: 0.337679, size: 4
#                         │   ├──252, impurity: 0, leaf_value: 1, size: 2
#                         │   └──253, impurity: 0.470007, leaf_value: 0, size: 2
#                         └──127, impurity: 0, leaf_value: 0, size: 4
#
# -----------------------------------------
# mode :              regression
# epochs :            3
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 86.8413 Metric va : 95.1125 Residuals (mean) : -508.197
# Epoch : 2     Metric Train : 78.4933 Metric va : 87.9114 Residuals (mean) : -457.378
# Epoch : 3     Metric Train : 70.9788 Metric va : 81.5735 Residuals (mean) : -411.64
# Save.
# FIT --- 0.019566774368286133 seconds ---
# PREDICT --- 9.632110595703125e-05 seconds ---
# accuracy_score: 0.42
# log_loss: 28.30
# f1_score: 0.00
# (array([0], dtype=int32), array([227]))
# FIT --- 0.05292558670043945 seconds ---
# PREDICT --- 6.461143493652344e-05 seconds ---
# [-2355.94640072]
# rmse: 56.28
# mae: 42.48
# r2: 0.79
# FIT --- 0.26968908309936523 seconds ---
# PREDICT --- 0.000240325927734375 seconds ---
# accuracy_score: 0.72
# log_loss: 16.81
# f1_score: 0.35
# (array([0, 1], dtype=int32), array([235,  65]))
# []
# Empty DataFrame
# Columns: []
# Index: []
# (0, 0)
# FIT --- 0.13973402976989746 seconds ---
# PREDICT --- 0.00011277198791503906 seconds ---
# [-508.19749172 -457.37774255 -411.63996829]
# rmse: 102.21
# mae: 81.57
# r2: 0.36
# 0

# %% [markdown]
# # make_regression

# %%
X, Y = sklearn.datasets.make_regression(n_samples=1000, n_features=8, n_informative=5, n_targets=1, noise=1, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
sys.path.append('/home/alexandre/Desktop/lltrees/build')
import lltrees
conf ={
    'epochs' : 1,
    'learning_rate' : 1,
    'metric' : 'mae', # Possible metrics for the moment : mae, mse
    'max_depth' : 5,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error",  # Possible metrics for the moment : variance, absolute_error
    'verbose' : 1, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              regression
# epochs :            1
# learning_rate :     1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# FIT --- 0.019247770309448242 seconds ---
# PREDICT --- 7.486343383789062e-05 seconds ---
# rmse: 63.46
# mae: 49.21
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 38.4851 Metric va : 49.2101 Residuals (mean) : -2355.95
# r2: 0.74

# %%
my_lltree = sklearn.tree.DecisionTreeRegressor(max_depth = 5, criterion ="absolute_error", random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print(YP[0:10])
print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.02142167091369629 seconds ---
# PREDICT --- 0.00023865699768066406 seconds ---
# [  -5.25635722  127.29805997 -110.4560012   122.24421396 -110.4560012
#   -39.90414254  106.73581898  -39.90414254  223.68925908  240.37517626]
# rmse: 63.68
# mae: 49.35
# r2: 0.74

# %%
conf ={
    'epochs' : 50,
    'learning_rate' : 0.1,
    'metric' : 'mae', # Possible metrics for the moment : mae, mse
    'max_depth' : 5,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error",  # Possible metrics for the moment : variance, absolute_error
    'verbose' : 0, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              regression
# epochs :            50
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           0
# -----------------------------------------
# FIT --- 0.9660835266113281 seconds ---
# PREDICT --- 0.0007543563842773438 seconds ---
# rmse: 27.59
# mae: 20.20
# r2: 0.95
# Type of Training Data : float64
# Configuration mode : regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
my_lltree = GradientBoostingRegressor(learning_rate = 0.1, n_estimators =50, max_depth = 5,
                                 loss = 'absolute_error', criterion = 'squared_error',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.2861595153808594 seconds ---
# PREDICT --- 0.0005974769592285156 seconds ---
# rmse: 34.85
# mae: 25.04
# r2: 0.92

# %% [markdown]
# # make_classification

# %%
X, Y = sklearn.datasets.make_classification(n_samples=1000, n_features=8, n_informative=5, n_classes=2, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
my_lltree = DecisionTreeClassifier(max_depth = 5, min_samples_split=5,
                                 splitter = 'best', criterion = 'gini',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# FIT --- 0.0040853023529052734 seconds ---
# PREDICT --- 0.00038123130798339844 seconds ---
# accuracy_score: 0.94
# log_loss: 3.80
# f1_score: 0.90

# %%
conf ={
    'mode' : 'classification',
    'epochs' : 1,
    'learning_rate' : 1,
    'metric' : 'accuracy',
    'max_depth' : 5,
    'min_leaf_size' : 5,
    'criterion' : "gini",  
    'verbose' : 1,  
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
# Out:
# FIT --- 0.09166073799133301 seconds ---
# PREDICT --- 0.00021529197692871094 seconds ---
# accuracy_score: 0.68
# -----------------------------------------
# mode :              classification
# epochs :            1
# learning_rate :     1
# metric :            accuracy
# criterion :         gini
# max_depth :         5
# min_leaf_size :     5
# verbose :           1
# -----------------------------------------
# Type of Training Data : int64
# Configuration mode : classification
# Gbt_classification fit
# All the distinct element for classification in sorted order are: 0 1
#
#
# Epoch : 1     Metric Train : 0.745714 Metric va : 0.74    Residuals (mean) : 0.745714
#
# log_loss: 18.42
# f1_score: 0.13
