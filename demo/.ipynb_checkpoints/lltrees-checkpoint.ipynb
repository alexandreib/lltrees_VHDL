# %%
import time

import numpy as np
import pandas as pd
import sklearn.datasets, sklearn.metrics, sklearn.model_selection, sklearn.tree

import subprocess, sys

# %%
# !cd ../ && make print-SOURCES
# Out:
# SOURCES = cpp/criterion.cpp cpp/factories.cpp cpp/gbt.cpp cpp/lltrees.cpp cpp/metrics.cpp cpp/node.cpp cpp/tree.cpp cpp/wrapper.cpp

# %%
# !cd ../ && make clean
# !cd ../ && make
subprocess.call([sys.executable, "lltrees_python_import_for_debug.py"])
# Out:
# rm -rf build
# mkdir -p build
# g++ -g -o build/criterion.o cpp/criterion.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/factories.o cpp/factories.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/gbt.o cpp/gbt.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/lltrees.o cpp/lltrees.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/metrics.o cpp/metrics.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/node.o cpp/node.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/tree.o cpp/tree.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/wrapper.o cpp/wrapper.cpp -I/usr/include/python3.10 -I/usr/include/python3.10  -Wno-unused-result -Wsign-compare -g      -fstack-protector-strong -Wformat -Werror=format-security  -DNDEBUG -g -fwrapv -O2 -Wall -fPIC -c -std=c++20 -DBOOST_BIND_GLOBAL_PLACEHOLDERS -DBOOST_ALLOW_DEPRECATED_HEADERS
# g++ -g -o build/lltrees.so build/criterion.o build/factories.o build/gbt.o build/lltrees.o build/metrics.o build/node.o build/tree.o build/wrapper.o -L/usr/lib/python3.10/config-3.10-x86_64-linux-gnu -L/usr/lib/x86_64-linux-gnu  -lcrypt -ldl  -lm -lm  -shared -Wl,-rpath,/usr/lib  -lpython3.10 -lboost_python310 -lboost_numpy310
# [[-1.13017873  2.91817356]
#  [-0.97972122 -2.12873409]]
# [ 159.09771799 -250.870943    165.74006195  110.75202167   63.47351979]
# -----------------------------------------
# mode :              regression
# epochs :            50
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     1
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 88.354  Metric va : 96.3501 Residuals (mean) : -508.197
# Epoch : 2     Metric Train : 81.2018 Metric va : 89.9313 Residuals (mean) : -457.378
# Epoch : 3     Metric Train : 74.6979 Metric va : 84.0295 Residuals (mean) : -411.64
# Epoch : 4     Metric Train : 68.8526 Metric va : 78.6383 Residuals (mean) : -370.476
# Epoch : 5     Metric Train : 63.4943 Metric va : 74.3066 Residuals (mean) : -333.428
# Epoch : 6     Metric Train : 58.7904 Metric va : 69.5122 Residuals (mean) : -300.086
# Epoch : 7     Metric Train : 54.3913 Metric va : 66.0215 Residuals (mean) : -270.077
# Epoch : 8     Metric Train : 50.381  Metric va : 62.7992 Residuals (mean) : -243.069
# Epoch : 9     Metric Train : 46.612  Metric va : 59.7048 Residuals (mean) : -218.762
# Epoch : 10    Metric Train : 43.3533 Metric va : 56.8551 Residuals (mean) : -196.886
# Epoch : 11    Metric Train : 40.3111 Metric va : 54.2561 Residuals (mean) : -177.198
# Epoch : 12    Metric Train : 37.6865 Metric va : 51.9961 Residuals (mean) : -159.478
# Epoch : 13    Metric Train : 35.2112 Metric va : 49.8803 Residuals (mean) : -143.53
# Epoch : 14    Metric Train : 32.7964 Metric va : 48.046  Residuals (mean) : -129.177
# Epoch : 15    Metric Train : 30.576  Metric va : 45.9853 Residuals (mean) : -116.259
# Epoch : 16    Metric Train : 28.8228 Metric va : 44.4407 Residuals (mean) : -104.633
# Epoch : 17    Metric Train : 27.0229 Metric va : 43.1419 Residuals (mean) : -94.17
# Epoch : 18    Metric Train : 25.385  Metric va : 41.6528 Residuals (mean) : -84.753
# Epoch : 19    Metric Train : 23.8436 Metric va : 40.2289 Residuals (mean) : -76.2777
# Epoch : 20    Metric Train : 22.5039 Metric va : 39.0499 Residuals (mean) : -68.6499
# Epoch : 21    Metric Train : 21.3037 Metric va : 38.105  Residuals (mean) : -61.785
# Epoch : 22    Metric Train : 20.1865 Metric va : 37.0515 Residuals (mean) : -55.6065
# Epoch : 23    Metric Train : 19.0431 Metric va : 36.1211 Residuals (mean) : -50.0458
# Epoch : 24    Metric Train : 18.1472 Metric va : 35.351  Residuals (mean) : -45.0412
# Epoch : 25    Metric Train : 17.2054 Metric va : 34.6514 Residuals (mean) : -40.5371
# Epoch : 26    Metric Train : 16.734  Metric va : 34.1739 Residuals (mean) : -36.4834
# Epoch : 27    Metric Train : 15.9535 Metric va : 33.5028 Residuals (mean) : -32.8351
# Epoch : 28    Metric Train : 15.2088 Metric va : 32.9496 Residuals (mean) : -29.5516
# Epoch : 29    Metric Train : 14.7902 Metric va : 32.6354 Residuals (mean) : -26.5964
# Epoch : 30    Metric Train : 14.0975 Metric va : 31.936  Residuals (mean) : -23.9368
# Epoch : 31    Metric Train : 13.4428 Metric va : 31.3861 Residuals (mean) : -21.5431
# Epoch : 32    Metric Train : 13.0636 Metric va : 31.0181 Residuals (mean) : -19.3888
# Epoch : 33    Metric Train : 12.536  Metric va : 30.5311 Residuals (mean) : -17.4499
# Epoch : 34    Metric Train : 12.4082 Metric va : 30.4448 Residuals (mean) : -15.7049
# Epoch : 35    Metric Train : 11.8631 Metric va : 29.9072 Residuals (mean) : -14.1344
# Epoch : 36    Metric Train : 11.5263 Metric va : 29.578  Residuals (mean) : -12.721
# Epoch : 37    Metric Train : 11.3885 Metric va : 29.4214 Residuals (mean) : -11.4489
# Epoch : 38    Metric Train : 11.1728 Metric va : 29.1883 Residuals (mean) : -10.304
# Epoch : 39    Metric Train : 10.7685 Metric va : 28.8718 Residuals (mean) : -9.27359
# Epoch : 40    Metric Train : 10.4482 Metric va : 28.5136 Residuals (mean) : -8.34623
# Epoch : 41    Metric Train : 10.1877 Metric va : 28.2679 Residuals (mean) : -7.51161
# Epoch : 42    Metric Train : 9.96306 Metric va : 28.0572 Residuals (mean) : -6.76045
# Epoch : 43    Metric Train : 9.70781 Metric va : 27.8635 Residuals (mean) : -6.0844
# Epoch : 44    Metric Train : 9.55925 Metric va : 27.713  Residuals (mean) : -5.47596
# Epoch : 45    Metric Train : 9.35129 Metric va : 27.5019 Residuals (mean) : -4.92837
# Epoch : 46    Metric Train : 9.11236 Metric va : 27.2157 Residuals (mean) : -4.43553
# Epoch : 47    Metric Train : 8.86969 Metric va : 26.8969 Residuals (mean) : -3.99198
# Epoch : 48    Metric Train : 8.82027 Metric va : 26.8433 Residuals (mean) : -3.59278
# Epoch : 49    Metric Train : 8.66261 Metric va : 26.6647 Residuals (mean) : -3.2335
# Epoch : 50    Metric Train : 8.52662 Metric va : 26.4542 Residuals (mean) : -2.91015
# FIT --- 1.357409954071045 seconds ---
# PREDICT --- 0.0004336833953857422 seconds ---
# [-508.19749172 -457.37774255 -411.63996829 -370.47597146 -333.42837432
#  -300.08553689 -270.0769832  -243.06928488 -218.76235639 -196.88612075
#  -177.19750868 -159.47775781 -143.52998203 -129.17698382 -116.25928544
#  -104.6333569   -94.17002121  -84.75301909  -76.27771718  -68.64994546
#   -61.78495091  -55.60645582  -50.04581024  -45.04122922  -40.5371063
#   -36.48339567  -32.8350561   -29.55155049  -26.59639544  -23.9367559
#   -21.54308031  -19.38877228  -17.44989505  -15.70490554  -14.13441499
#   -12.72097349  -11.44887614  -10.30398853   -9.27358967   -8.34623071
#    -7.51160764   -6.76044687   -6.08440219   -5.47596197   -4.92836577
#    -4.43552919   -3.99197627   -3.59277865   -3.23350078   -2.9101507 ]
# rmse: 34.97
# mae: 26.45
# r2: 0.93
# -----------------------------------------
# mode :              regression
# epochs :            50
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     1
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 88.354  Metric va : 96.3501 Residuals (mean) : -508.197
# Epoch : 2     Metric Train : 81.2018 Metric va : 89.9313 Residuals (mean) : -457.378
# Epoch : 3     Metric Train : 74.6979 Metric va : 84.0295 Residuals (mean) : -411.64
# Epoch : 4     Metric Train : 68.8526 Metric va : 78.6383 Residuals (mean) : -370.476
# Epoch : 5     Metric Train : 63.4943 Metric va : 74.3066 Residuals (mean) : -333.428
# Epoch : 6     Metric Train : 58.7904 Metric va : 69.5122 Residuals (mean) : -300.086
# Epoch : 7     Metric Train : 54.3913 Metric va : 66.0215 Residuals (mean) : -270.077
# Epoch : 8     Metric Train : 50.381  Metric va : 62.7992 Residuals (mean) : -243.069
# Epoch : 9     Metric Train : 46.612  Metric va : 59.7048 Residuals (mean) : -218.762
# Epoch : 10    Metric Train : 43.3533 Metric va : 56.8551 Residuals (mean) : -196.886
# Epoch : 11    Metric Train : 40.3111 Metric va : 54.2561 Residuals (mean) : -177.198
# Epoch : 12    Metric Train : 37.6865 Metric va : 51.9961 Residuals (mean) : -159.478
# Epoch : 13    Metric Train : 35.2112 Metric va : 49.8803 Residuals (mean) : -143.53
# Epoch : 14    Metric Train : 32.7964 Metric va : 48.046  Residuals (mean) : -129.177
# Epoch : 15    Metric Train : 30.576  Metric va : 45.9931 Residuals (mean) : -116.259
# Epoch : 16    Metric Train : 28.8228 Metric va : 44.4485 Residuals (mean) : -104.633
# Epoch : 17    Metric Train : 27.0229 Metric va : 43.1497 Residuals (mean) : -94.17
# Epoch : 18    Metric Train : 25.385  Metric va : 41.6551 Residuals (mean) : -84.753
# Epoch : 19    Metric Train : 23.8436 Metric va : 40.2312 Residuals (mean) : -76.2777
# Epoch : 20    Metric Train : 22.5039 Metric va : 39.0576 Residuals (mean) : -68.6499
# Epoch : 21    Metric Train : 21.3037 Metric va : 38.1127 Residuals (mean) : -61.785
# Epoch : 22    Metric Train : 20.1865 Metric va : 37.0847 Residuals (mean) : -55.6065
# Epoch : 23    Metric Train : 19.0431 Metric va : 36.1543 Residuals (mean) : -50.0458
# Epoch : 24    Metric Train : 18.1472 Metric va : 35.3762 Residuals (mean) : -45.0412
# Epoch : 25    Metric Train : 17.2054 Metric va : 34.6816 Residuals (mean) : -40.5371
# Epoch : 26    Metric Train : 16.734  Metric va : 34.1898 Residuals (mean) : -36.4834
# Epoch : 27    Metric Train : 15.9535 Metric va : 33.5187 Residuals (mean) : -32.8351
# Epoch : 28    Metric Train : 15.2088 Metric va : 32.9656 Residuals (mean) : -29.5516
# Epoch : 29    Metric Train : 14.7902 Metric va : 32.6513 Residuals (mean) : -26.5964
# Epoch : 30    Metric Train : 14.0975 Metric va : 31.9519 Residuals (mean) : -23.9368
# Epoch : 31    Metric Train : 13.4428 Metric va : 31.402  Residuals (mean) : -21.5431
# Epoch : 32    Metric Train : 13.0636 Metric va : 31.034  Residuals (mean) : -19.3888
# Epoch : 33    Metric Train : 12.536  Metric va : 30.5471 Residuals (mean) : -17.4499
# Epoch : 34    Metric Train : 12.4082 Metric va : 30.4608 Residuals (mean) : -15.7049
# Epoch : 35    Metric Train : 11.8631 Metric va : 29.9232 Residuals (mean) : -14.1344
# Epoch : 36    Metric Train : 11.5263 Metric va : 29.6018 Residuals (mean) : -12.721
# Epoch : 37    Metric Train : 11.3885 Metric va : 29.4451 Residuals (mean) : -11.4489
# Epoch : 38    Metric Train : 11.1728 Metric va : 29.2079 Residuals (mean) : -10.304
# Epoch : 39    Metric Train : 10.7685 Metric va : 28.8913 Residuals (mean) : -9.27359
# Epoch : 40    Metric Train : 10.4482 Metric va : 28.5332 Residuals (mean) : -8.34623
# Epoch : 41    Metric Train : 10.1877 Metric va : 28.2897 Residuals (mean) : -7.51161
# Epoch : 42    Metric Train : 9.96306 Metric va : 28.0791 Residuals (mean) : -6.76045
# Epoch : 43    Metric Train : 9.70781 Metric va : 27.8853 Residuals (mean) : -6.0844
# Epoch : 44    Metric Train : 9.55925 Metric va : 27.7348 Residuals (mean) : -5.47596
# Epoch : 45    Metric Train : 9.35129 Metric va : 27.5237 Residuals (mean) : -4.92837
# Epoch : 46    Metric Train : 9.11236 Metric va : 27.2375 Residuals (mean) : -4.43553
# Epoch : 47    Metric Train : 8.86969 Metric va : 26.9187 Residuals (mean) : -3.99198
# Epoch : 48    Metric Train : 8.82027 Metric va : 26.8651 Residuals (mean) : -3.59278
# Epoch : 49    Metric Train : 8.66261 Metric va : 26.6865 Residuals (mean) : -3.2335
# Epoch : 50    Metric Train : 8.52662 Metric va : 26.476  Residuals (mean) : -2.91015
# FIT --- 1.3808810710906982 seconds ---
# PREDICT --- 0.0004277229309082031 seconds ---
# [-508.19749172 -457.37774255 -411.63996829 -370.47597146 -333.42837432
#  -300.08553689 -270.0769832  -243.06928488 -218.76235639 -196.88612075
#  -177.19750868 -159.47775781 -143.52998203 -129.17698382 -116.25928544
#  -104.6333569   -94.17002121  -84.75301909  -76.27771718  -68.64994546
#   -61.78495091  -55.60645582  -50.04581024  -45.04122922  -40.5371063
#   -36.48339567  -32.8350561   -29.55155049  -26.59639544  -23.9367559
#   -21.54308031  -19.38877228  -17.44989505  -15.70490554  -14.13441499
#   -12.72097349  -11.44887614  -10.30398853   -9.27358967   -8.34623071
#    -7.51160764   -6.76044687   -6.08440219   -5.47596197   -4.92836577
#    -4.43552919   -3.99197627   -3.59277865   -3.23350078   -2.9101507 ]
# rmse: 35.03
# mae: 26.48
# r2: 0.92
# [ 126.37675452   98.64490452 -173.13506278  -25.03101711   -7.09649346
#    98.60648348  122.50643379   49.74961172  -36.89865572  -12.86042031]
# 0

# %% [markdown]
# # make_regression

# %%
X, Y = sklearn.datasets.make_regression(n_samples=1000, n_features=8, n_informative=5, n_targets=1, noise=1, random_state=42)
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
sys.path.append('/home/alexandre/Desktop/lltrees/build')
import lltrees
conf ={
    'epochs' : 1,
    'learning_rate' : 1,
    'metric' : 'mae', # Possible metrics for the moment : mae, mse
    'max_depth' : 5,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error",  # Possible metrics for the moment : variance, absolute_error
    'verbose' : 1, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# -----------------------------------------
# mode :              regression
# epochs :            FIT --- 0.020393848419189453 seconds ---
# PREDICT --- 7.653236389160156e-05 seconds ---
# rmse: 63.46
# mae: 49.21
# r2: 0.74
# 1
# learning_rate :     1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           1
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression
# Epoch : 1     Metric Train : 38.4851 Metric va : 49.2101 Residuals (mean) : -2355.95

# %%
my_lltree = sklearn.tree.DecisionTreeRegressor(max_depth = 5, criterion ="absolute_error", random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print(YP[0:10])
print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.024437904357910156 seconds ---
# PREDICT --- 0.000225067138671875 seconds ---
# [  -5.25635722  127.29805997 -110.4560012   122.24421396 -110.4560012
#   -39.90414254  106.73581898  -39.90414254  223.68925908  240.37517626]
# rmse: 63.68
# mae: 49.35
# r2: 0.74

# %%
conf ={
    'epochs' : 50,
    'learning_rate' : 0.1,
    'metric' : 'mae', # Possible metrics for the moment : mae, mse
    'max_depth' : 5,
    'min_leaf_size' : 2,
    'criterion' : "absolute_error",  # Possible metrics for the moment : variance, absolute_error
    'verbose' : 0, 
}
my_lltree = lltrees.lltree()
my_lltree.set_conf(conf)
my_lltree.get_conf()

start_time = time.time()
my_lltree.fit(X_train, Y_train, X_test, Y_test)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.9614264965057373 seconds ---
# PREDICT --- 0.0005216598510742188 seconds ---
# rmse: 28.65
# mae: 21.25
# r2: 0.95
# -----------------------------------------
# mode :              regression
# epochs :            50
# learning_rate :     0.1
# metric :            mae
# criterion :         absolute_error
# max_depth :         5
# min_leaf_size :     2
# verbose :           0
# -----------------------------------------
# Type of Training Data : float64
# Configuration mode : regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
my_lltree = GradientBoostingRegressor(learning_rate = 0.1, n_estimators =50, max_depth = 5,
                                 loss = 'absolute_error', criterion = 'squared_error',
                                 random_state = 0)

start_time = time.time()
my_lltree.fit(X_train, Y_train)
print("FIT --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
YP = my_lltree.predict(X_test)
print("PREDICT --- %s seconds ---" % (time.time() - start_time))

print("rmse: %.2f" % np.sqrt(sklearn.metrics.mean_squared_error(Y_test,YP)))
print("mae: %.2f" % sklearn.metrics.mean_absolute_error(Y_test,YP))
print("r2: %.2f" % sklearn.metrics.r2_score(Y_test,YP))
# Out:
# FIT --- 0.2818641662597656 seconds ---
# PREDICT --- 0.0005903244018554688 seconds ---
# rmse: 34.85
# mae: 25.04
# r2: 0.92

# %% [markdown]
# # make_classification

# %%
# X, Y = sklearn.datasets.make_classification(n_samples=1000, n_features=8, n_informative=5, n_classes=2, random_state=42)
# X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# conf ={
#     'epochs' : 50,
#     'learning_rate' : 0.1,
#     'metric_name' : 'mae', # Possible metrics for the moment : mae, mse
#     'lltree_max_depth' : 3,
#     'lltree_min_size_split' : 1,
#     'lltree_criterion' : "gini",  # Possible metrics for the moment : variance, absolute_error
#     'verbose' : 1,  # Possible metrics for the moment : variance, absolute_error
# }
# my_lltree = lltrees.lltree()
# my_lltree.set_conf(conf)
# my_lltree.get_conf()

# start_time = time.time()
# my_lltree.fit(X_train, Y_train)
# print("FIT --- %s seconds ---" % (time.time() - start_time))

# start_time = time.time()
# YP = my_lltree.predict(X_test)
# print("PREDICT --- %s seconds ---" % (time.time() - start_time))

# print("accuracy_score: %.2f" % np.sqrt(sklearn.metrics.accuracy_score(Y_test,YP)))
# print("log_loss: %.2f" % sklearn.metrics.log_loss(Y_test,YP))
# print("f1_score: %.2f" % sklearn.metrics.f1_score(Y_test,YP))
